# %%
import psycopg2
from psycopg2 import sql
import pandas as pd  # Already imported

# %%
# Install
# !pip install supabase

# Use service role key in your notebook
from supabase import create_client

url = "https://rfeqnthiyhzoqfyhqlay.supabase.co"  # From Project Settings → API
service_key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InJmZXFudGhpeWh6b3FmeWhxbGF5Iiwicm9sZSI6InNlcnZpY2Vfcm9sZSIsImlhdCI6MTc1OTc3MDEzMSwiZXhwIjoyMDc1MzQ2MTMxfQ.GJ1anYyTDs2rPeVq5piX2jBBA-Sc5RVhcjRS0fBwkm8"  # Service role key from same place

supabase = create_client(url, service_key)

# %%
response = supabase.table("students").select("*").execute()

# %%
data = response.data
print(data)
# Out:
# [{'student_id': 'a654b3c4-50e2-4e6f-a5ae-6a29204f3853', 'user_id': '0a6cd3e0-0a85-4e72-b6fe-249c3b4b436c', 'admission_number': 'LPS20200000', 'class_id': '010e7eee-c3c6-4359-a62f-4c7148c1a317', 'date_of_admission': '2020-01-01', 'status': 'dropped_out', 'dropout_date': '2024-09-18', 'dropout_reason': 'Health issues'}, {'student_id': '7419ed6c-b885-4696-beaf-107ba46d6ff6', 'user_id': '1ad8c372-1440-4dc9-aeba-bf1223722922', 'admission_number': 'LPS20200001', 'class_id': '010e7eee-c3c6-4359-a62f-4c7148c1a317', 'date_of_admission': '2019-05-29', 'status': 'active', 'dropout_date': None, 'dropout_reason': None}, {'student_id': 'c6488898-8dcf-44fc-8838-274f632d8bc8', 'user_id': '15a3fd12-3cf8-4d9d-97b5-8b6559480583', 'admission_number': 'LPS20200002', 'class_id': '010e7eee-c3c6-4359-a62f-4c7148c1a317', 'date_of_admission': '2019-05-29', 'status': 'active', 'dropout_date': None, 'dropout_reason': None}, {'student_id': '899f4302-6616-44ef-9bcc-e554ef6b2f9e', 'user_id': '2049eaf5-e4f3-4b34-81
# ...

# %%
import pandas as pd

df = pd.DataFrame(response.data)
df.head()
# Out:
#                              student_id                               user_id  \
# 0  a654b3c4-50e2-4e6f-a5ae-6a29204f3853  0a6cd3e0-0a85-4e72-b6fe-249c3b4b436c
# 1  7419ed6c-b885-4696-beaf-107ba46d6ff6  1ad8c372-1440-4dc9-aeba-bf1223722922
# 2  c6488898-8dcf-44fc-8838-274f632d8bc8  15a3fd12-3cf8-4d9d-97b5-8b6559480583
# 3  899f4302-6616-44ef-9bcc-e554ef6b2f9e  2049eaf5-e4f3-4b34-81c9-e776ea4f8163
# 4  48f71c24-143d-4acd-8ca1-9a7b3a844535  0635a719-04fb-45a9-abfc-9173068e7634
#
#   admission_number                              class_id date_of_admission  \
# 0      LPS20200000  010e7eee-c3c6-4359-a62f-4c7148c1a317        2020-01-01
# 1      LPS20200001  010e7eee-c3c6-4359-a62f-4c7148c1a317        2019-05-29
# 2      LPS20200002  010e7eee-c3c6-4359-a62f-4c7148c1a317        2019-05-29
# 3      LPS20200003  010e7eee-c3c6-4359-a62f-4c7148c1a317        2019-02-23
# 4      LPS20200004  010e7eee-c3c6-4359-a62f-4c7148c1a317        2019-11-12
#
#         status dropout_date dropout_reason
# ...

# %%
tables = [
    "buses", "class_attendance", "classes", "exams",
    "fee_payments", "route_stops", "routes", "schools",
    "student_parents", "student_results", "student_transport",
    "student_transport_logs", "students", "subjects",
    "terms", "users"
]

data = {}

for table in tables:
    response = supabase.table(table).select("*").execute()
    data[table] = response.data  # store each table's data in a dictionary

print(f"✅ Loaded {len(data)} tables successfully!")
# Out:
# ✅ Loaded 16 tables successfully!

# %%
# View all columns for each table
print("\n📋 Table Schemas (Column Names):")
for table_name, table_data in data.items():
    if table_data:  # Skip if empty
        columns = list(table_data[0].keys())  # Get columns from first row
        print(f"\n{table_name}: {', '.join(columns)}")
    else:
        print(f"\n{table_name}: [Empty table - no columns to display]")
# Out:
# 📋 Table Schemas (Column Names):
#
# buses: bus_id, bus_number, capacity, driver_user_id
#
# class_attendance: attendance_id, student_id, class_id, date, term_id, status, recorded_at
#
# classes: class_id, school_id, grade_level, class_name, class_teacher_id, capacity
#
# exams: exam_id, term_id, exam_type, exam_date, class_id
#
# fee_payments: payment_id, student_id, term_id, amount_required, amount_paid, balance, payment_status, last_payment_date
#
# route_stops: stop_id, route_id, stop_name, stop_order, latitude, longitude, time_from_prev_stop_min
#
# routes: route_id, route_name, total_distance_km, estimated_duration_min
#
# schools: school_id, name, county, created_at
#
# student_parents: id, student_id, parent_user_id, relationship, is_primary
#
# student_results: result_id, student_id, exam_id, subject_id, marks, class_mean, class_rank, recorded_at
#
# student_transport: id, student_id, bus_id, pickup_stop_id, dropoff_stop_id, is_active
#
# ...
